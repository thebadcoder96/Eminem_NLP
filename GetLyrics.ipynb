# %%
# %%javascript
# IPython.notebook.clear_all_output();

# %% [markdown]
# # Collect Songs Data From Genius

# %%
import lyricsgenius
import os
import pandas as pd
import json 

genius = lyricsgenius.Genius("u8YSHFnB7rwHvt7c49CJ9tsFDwqsfXJt-0F13h-MdtpeKS-rnycyCj_PTcJ3yE4I")

# %%
#Searching by artist 

#artist = genius.search_artist("Eminem", max_songs=5)


artist = genius.search_artist("Eminem")
# Out:
# Searching for songs by Eminem...
#
# Song 1: "Rap God"
# Song 2: "Killshot"
# Song 3: "Lose Yourself"
# Song 4: "The Monster"
# Song 5: "Lucky You"
# Song 6: "The Ringer"
# Song 7: "Godzilla"
# Song 8: "River"
# Song 9: "Berzerk"
# Song 10: "Venom"
# Song 11: "Not Alike"
# Song 12: "Fall"
# Song 13: "Stan"
# Song 14: "Without Me"
# Song 15: "Walk on Water"
# Song 16: "The Real Slim Shady"
# Song 17: "Kamikaze"
# Song 18: "Bad Guy"
# Song 19: "’Till I Collapse"
# Song 20: "Love the Way You Lie"
# Song 21: "Mockingbird"
# Song 22: "8 Mile: B-Rabbit vs Papa Doc"
# Song 23: "Headlights"
# Song 24: "Survival"
# Song 25: "Not Afraid"
# Song 26: "No Love"
# Song 27: "Beautiful"
# Song 28: "Greatest"
# Song 29: "When I’m Gone"
# Song 30: "Love Game"
# Song 31: "Legacy"
# Song 32: "My Name Is"
# Song 33: "Cleanin’ Out My Closet"
# Song 34: "The Way I Am"
# Song 35: "Space Bound"
# Song 36: "Like Toy Soldiers"
# Song 37: "Guts Over Fear"
# Song 38: "Superman"
# Song 39: "Sing for the Moment"
# ...

# %%
#Save as a json file

artist.save_lyrics()
# Out:
# Wrote `Lyrics_Eminem.json`

# %% [markdown]
# #### References
#
#  - LyricsGenius by John W. Miller https://github.com/johnwmillr/LyricsGenius
